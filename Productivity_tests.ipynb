# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 21.7 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.2 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 3.3 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.0 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.5 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
# ...

# %%
from ultralytics import YOLO
import cv2
import os
from IPython.display import Video, display
import time

# YOLO11s
model = YOLO('/kaggle/input/detract-yolo11s/kaggle/working/runs/detect/train/weights/best.pt') 

input_path = '/kaggle/input/base-de-datos-de-videos-de-transito-vehicular/39031.avi'
output_path = '/kaggle/working/output.mp4'

cap = cv2.VideoCapture(input_path)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))


total_inference_time = 0
processed_frames = 0

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    start_time = time.time()
    results = model.predict(source=frame,verbose=False)
    inference_time = time.time() - start_time
    total_inference_time += inference_time

    annotated_frame = results[0].plot()
    out.write(annotated_frame)

    processed_frames += 1

cap.release()
out.release()

avg_inference_time = total_inference_time / processed_frames
avg_fps = 1 / avg_inference_time

print(f"Total frames processed: {processed_frames}")
print(f"Total inference time: {total_inference_time:.2f} seconds")
print(f"Average inference time per frame: {avg_inference_time*1000:.2f} ms")
print(f"Average FPS: {avg_fps:.2f}")
# Out:
# Total frames processed: 1470
# Total inference time: 16.93 seconds
# Average inference time per frame: 11.51 ms
# Average FPS: 86.85

# %%
from ultralytics import YOLO
import cv2
import os
from IPython.display import Video, display
import time

# YOLO10s
model = YOLO('/kaggle/input/detract-yolo8s-and-yolo10s/kaggle/working/runs/detect/train/weights/best.pt')  # заміни шлях

input_path = '/kaggle/input/base-de-datos-de-videos-de-transito-vehicular/39031.avi'
output_path = '/kaggle/working/output.mp4'

cap = cv2.VideoCapture(input_path)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

total_inference_time = 0
processed_frames = 0

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    start_time = time.time()
    results = model.predict(source=frame,verbose=False)
    inference_time = time.time() - start_time
    total_inference_time += inference_time

    annotated_frame = results[0].plot()
    out.write(annotated_frame)

    processed_frames += 1

cap.release()
out.release()

avg_inference_time = total_inference_time / processed_frames
avg_fps = 1 / avg_inference_time

print(f"Total frames processed: {processed_frames}")
print(f"Total inference time: {total_inference_time:.2f} seconds")
print(f"Average inference time per frame: {avg_inference_time*1000:.2f} ms")
print(f"Average FPS: {avg_fps:.2f}")
# Out:
# Total frames processed: 1470
# Total inference time: 15.48 seconds
# Average inference time per frame: 10.53 ms
# Average FPS: 94.99

# %%
from ultralytics import YOLO
import cv2
import os
from IPython.display import Video, display
import time

# YOLO8s
model = YOLO('/kaggle/input/detract-yolo8s-and-yolo10s/kaggle/working/runs/detect/train2/weights/best.pt')  # заміни шлях

input_path = '/kaggle/input/base-de-datos-de-videos-de-transito-vehicular/39031.avi'
output_path = '/kaggle/working/output.mp4'

cap = cv2.VideoCapture(input_path)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

total_inference_time = 0
processed_frames = 0

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    start_time = time.time()
    results = model.predict(source=frame,verbose=False)
    inference_time = time.time() - start_time
    total_inference_time += inference_time

    annotated_frame = results[0].plot()
    out.write(annotated_frame)

    processed_frames += 1

cap.release()
out.release()

avg_inference_time = total_inference_time / processed_frames
avg_fps = 1 / avg_inference_time

print(f"Total frames processed: {processed_frames}")
print(f"Total inference time: {total_inference_time:.2f} seconds")
print(f"Average inference time per frame: {avg_inference_time*1000:.2f} ms")
print(f"Average FPS: {avg_fps:.2f}")
# Out:
# Total frames processed: 1470
# Total inference time: 15.19 seconds
# Average inference time per frame: 10.33 ms
# Average FPS: 96.79

# %%
from ultralytics import YOLO

model = YOLO("/kaggle/input/yolo11s-weights/kaggle/working/runs/detect/train/weights/best.pt")
results = model("/kaggle/input/base-de-datos-de-videos-de-transito-vehicular/39031.avi", save=True, show=True)
